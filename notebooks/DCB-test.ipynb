# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join("..", "src")))

from modules.NumericalModel import NumericalModel
from modules.PDFatigueModel import FatigueInputData, PDFatigueSolver
import numpy as np
import matplotlib.pyplot as plt
import libs.pddopyW2 as pddo

# %% [markdown]
# ## "NumericalModel" class
# The "NumericalModel" type is somprised of so called "modules". These modules are
# 1. Geometry module          ->  NumericalModel.Geometry
# 2. Discretisations module   ->  NumericalModel.Discretisations
# 3. Materials module         ->  NumericalModel.Materials
# 4. Interactions module      ->  NumericalModel.Interactions
#
# Each module has its own main class with the same name as the module.\
# The module itself (as in the file where the code is stored) is named with NON-prime letters, while the class inside is primed!
#
# To explain this further it is shown below that the class from each module is imported into the "NumericalModel" type in the following way:
#
# class NumericalModel():
#
#     def __init__(self,name: str = "Model") -> None:
#         self.name = name
#         self.Geometry = geometry.Geometry()
#         self.Materials= material.Materials()
#         self.Loads = loads.BoundaryCons()
#         self.Discretizations = disretization.Discretizations()
#         self.Interactions = interactions.Interactions()
#         self.SimulationSettings = simulation_settings.SimulationSettings()
#
# This way, when we call a module in the "NumericalModel" instance we directly call the main class if the module with the same name.\
# Each of the module classes will be explained during their use!

# %% [markdown]
# ## Create a "NumericalModel" instance

# %%
# Create a NumericalModel
model0 = NumericalModel()

# %% [markdown]
# ## Geometry module
#
# The geometry module is meant to hold the points that define the whole model. Each point is created as a "PartNodes" type and is saved in the "part_nodes: PartNodes" attribute of the Geometry class.\
# The "PartNodes" class is simply a dictionary (hashTable) of all the points in the points in the model.\
# Each point is saved as a "Node" type. This type contains the data of each points such as its ID and coordinates.\
# Each "Node" can be searched for in the "part_nodes: PartNodes" attribute, using the nodes ID number.
#
# Currently only one part can be created meaning only one "part_nodes: PartNodes" object which contains the dictionary of "Node"s can exist in a single model.

# %%
# To create a PartNodes instance in the Geometry modules, we must first have some point with which we define the models geometry.
# I have used a simple example of a rectangular plate with a hole in the middle.
# The data is read from a txt file that conatins coordinates of each point -> each line index in the txt file represents an ID of a point.
# So the points are wirtten in ascending order in terms of ID!s 
# We also define a "dx" variable which will store the distance between two neighboring points.
# Using this dx we also create an array that stores the are of each point.
coordVec = np.loadtxt(fname= "../Testing data/DCB-coordVec2.txt")/1000
dx = coordVec[1,0] - coordVec[0,0] 
nodeVolumes = np.loadtxt(fname= "../testing data/DCB-volumes2.txt")/1000000
# inclusionIds = np.loadtxt(fname= "../Testing input data/inclusionPlate-inclusionIds.txt",dtype=np.int64)
# matrixIds = np.loadtxt(fname= "../Testing input data/inclusionPlate-matrixIds.txt",dtype=np.int64)

# %%
# To define the geometry od the model, we access the geometry modules method "input_part_nodes"
# This method takes array of points coordinates and an aray of point areas and creates the "PartNodes" instance and saves it in 
# the "part_nodes: PartNodes" attribute of the Geometry class.
model0.Geometry.input_part_nodes(inputCoordinates=coordVec,inputVolumes=nodeVolumes)

# %%
# If we now use the "get_part_nodes" method on the "part_nodes" attribute (which is now of type "PartNodes"),
#we can return all the nodes in the model
part_nodes = model0.Geometry.part_nodes.get_part_nodes()
#model0.Geometry.part_nodes.get_part_nodes()

# As we can see, this return the dictionary stored in the "PartNodes" instance.
# The (Key,Value) pairs represent the ID of a node and the node itself (as a type) -> (ID, "Node")

# We can also call a specific node and then its attributes in the following way
part_nodes[0].all_data()
# Out:
# [0, [0.0, 0.0], 4e-06]

# %% [markdown]
# # Data module
#
# The data module is meant to hold general data objects such as sets. It is structured so that we have a "Sets" class that stores many "Set" object instances. Currenlty sets are used only to store ID's as is explained in the following code

# %%
# We can also define specific sets of points.
# For example lets create a set for each laoding condition we want tin the model.
# Lets go for a stretch in the y deirection. Both the top and bottom points should be displaced upward and downward respectively.
# Because the point were saved in the txt file in a specific way, we define
totint,totbottom,tottop =9684, 9984, 80601 #number of points in main reagion of plate, number of points in omain and bottom set, total number of internal bottom and top points combined
ndivx,nnum =800, coordVec.shape[0]
# To define a set, we go into the goemtry module and into the "sets: Sets" attribute of the geometry module.
# This attribute is a Sets type which stores a table of all sets in the model. 
# To create a set we call the "create_set()" method of the "Sets" type and input the list of node ID's we want in the set and the sets name!
# changed_top = np.array([range(nnum-3*201,nnum-3*201+50),range(nnum-2*201,nnum-2*201+50),range(nnum-1*201,nnum-1*201+50)],dtype=np.int64).flatten()
model0.Geometry.sets.create_set(np.arange(0,nnum/2,1,dtype=int),setName="botHalf")
model0.Geometry.sets.create_set(np.arange(nnum-nnum/2,nnum,1,dtype=int),setName="topHalf")
model0.Geometry.sets.create_set(np.array([199 + i*200 for i in range(30)],dtype=int),setName="RightFixture")
model0.Geometry.sets.create_set(np.array([(10*200)+10],dtype=int),setName="LeftDownLoad")
model0.Geometry.sets.create_set(np.array([(20*200)+10],dtype=int),setName="LeftUpLoad")

# %%
# As can be seen from the code below, "sets" contains multiple "Set" instances. We can access the table of "Set" instances as shown below.
# Each "Set" instance contains the name of the set and the array of ID's of the nodes in the set.
SetIDs = model0.Geometry.sets.setTable["botHalf"].get_data()
SetIDs2 = model0.Geometry.sets.setTable["topHalf"].get_data()
SetIDs3 = model0.Geometry.sets.setTable["RightFixture"].get_data()
SetIDs4 = model0.Geometry.sets.setTable["LeftUpLoad"].get_data()
SetIDs5 = model0.Geometry.sets.setTable["LeftDownLoad"].get_data()
botHalfSet = model0.Geometry.sets.setTable["botHalf"]
topHalfSet = model0.Geometry.sets.setTable["topHalf"]
rightFixSet = model0.Geometry.sets.setTable["RightFixture"]
LeftUpLoadSet = model0.Geometry.sets.setTable["LeftUpLoad"]
LeftDownLoadSet = model0.Geometry.sets.setTable["LeftDownLoad"]

# %%
# Graphical representation of the plate with a hole. The blue points are the points in the first set and the red points are from the second set.
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot()
# ax.scatter(coordVec[:,0],coordVec[:,1],s =1)
ax.scatter(coordVec[SetIDs,0],coordVec[SetIDs,1],s=0.6,c = "r")
ax.scatter(coordVec[SetIDs2,0],coordVec[SetIDs2,1],s=0.6,c = "b")
ax.scatter(coordVec[SetIDs3,0],coordVec[SetIDs3,1],s=10,c = "green")
ax.set_aspect(1)

# %% [markdown]
# # Material Module
#
# This module works in mostly the same way as the data module. The  main class is the "Materials" class which lets us create single "Materil" type instances that are then stored in the "Materials" modules "materialTable" dictionary.

# %%
model0.Materials.create_material(materialName="Steel1")
model0.Materials.materialsTable["Steel1"].set_tensile_properties(youngMod = 220e9, poisson =0.25)
model0.Materials.materialsTable["Steel1"].get_material_properties()

model0.Materials.create_material(materialName="Steel2")
model0.Materials.materialsTable["Steel2"].set_tensile_properties(youngMod = 220e9, poisson =0.25)
model0.Materials.materialsTable["Steel2"].get_material_properties()

model0.Materials.create_material(materialName="InterfaceSteel")
model0.Materials.materialsTable["InterfaceSteel"].set_tensile_properties(youngMod = 200e9, poisson =0.25)
model0.Materials.materialsTable["InterfaceSteel"].get_material_properties()

steel1 = model0.Materials.materialsTable["Steel1"]
steel1.set_stretch_thresholds(damageInitStretch=0.7, breakageStretch=0.4)
steel2 = model0.Materials.materialsTable["Steel2"]
steel2.set_stretch_thresholds(damageInitStretch=0.7, breakageStretch=0.4)
interface_steel = model0.Materials.materialsTable["InterfaceSteel"]
interface_steel.set_stretch_thresholds(damageInitStretch=0.001406, breakageStretch=0.20168)

# %%
s1 = 5* 450/(200000*8)
sc = 2* np.pi * 260 /(3* 450*6)
s1,sc
# Out:
# (0.00140625, 0.20168249134156696)

# %%
botHalfSet.get_data()
# Out:
# array([   0,    1,    2, ..., 2997, 2998, 2999])

# %%
model0.Geometry.sets.create_set(arrayOfIDs=botHalfSet.get_data(), setName = "BotSteel1Section")
model0.Geometry.sets.create_set(arrayOfIDs=topHalfSet.get_data(), setName = "TopSteel2Section")
model0.MaterialSections.create(nodeSet=model0.Geometry.sets.setTable["BotSteel1Section"],material=steel1, name = "Steel1Section")
model0.MaterialSections.create(nodeSet=model0.Geometry.sets.setTable["TopSteel2Section"],material=steel2, name = "Steel2Section")

# %%
steel1Section = model0.MaterialSections.materialSectionsTable["Steel1Section"]
steel2Section = model0.MaterialSections.materialSectionsTable["Steel2Section"]

# %%
model0.MaterialInterfaces.create(materialSection1=steel1Section,materialSection2=steel2Section,material=interface_steel)

# %% [markdown]
# # Discretisaton module
#
# Again... we have a main "Discretisations" class through which we create single "Discretisation" type instances.

# %%
model0.Discretizations.create_discretization("TestDisc")

# %%
model0.Discretizations.discretizationsTable["TestDisc"].set_horizon(3*dx)
model0.Discretizations.discretizationsTable["TestDisc"].create_crack(p1x = -0.1,p2x = 0.0999,p1y = 0.029,p2y = 0.029)
model0.Discretizations.discretizationsTable["TestDisc"].generate_bonds(partNodes = model0.Geometry.part_nodes)

# %%
# model0.Discretizations.discretizationsTable["TestDisc"].initialCracks

# %%
model0.Discretizations.discretizationsTable["TestDisc"].is_crack_active()
# Out:
# True

# %%
testDisc = model0.Discretizations.discretizationsTable["TestDisc"]
model0.Discretizations.set_selected_discretization(DiscretizationName="TestDisc")

# %%
data = testDisc.get_node_family_coords(4010)
fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot()
size=0.5
ax.scatter(coordVec[:,0],coordVec[:,1],s = size)
ax.scatter(coordVec[SetIDs,0],coordVec[SetIDs,1],c = "r",s=size)
ax.scatter(coordVec[SetIDs2,0],coordVec[SetIDs2,1],c = "b",s=size)
ax.scatter(data[:,0],data[:,1],s=5,c="green")
ax.set_aspect(1)
# plt.xlim(0.035,0.04)
# plt.ylim(0.0,0.0024)

# %% [markdown]
# # Loads module

# %%
#Not needed since i want to apply a uniform displacement field
model0.Loads.create_disp_load(nodeSet = rightFixSet, dispX = 0.0, dispY= 0.0, name="RightFixture")
model0.Loads.create_disp_load(nodeSet = LeftUpLoadSet,dispY = 0.02, name="LeftLoadUp")
model0.Loads.create_disp_load(nodeSet = LeftDownLoadSet,dispY = -0.02, name="LeftLoadDown")

# %% [markdown]
# # PDFatigueModel

# %%
fatigueModelData = FatigueInputData(numModel = model0)

# %%
lines = np.zeros(shape=(testDisc.neighbors.shape[0],4))
for point in range(coordVec.shape[0]):
    for bond in range(testDisc.start_idx[point],testDisc.end_idx[point]):
        j_point_id = testDisc.neighbors[bond]
        lines[bond,0] = coordVec[point,0]
        lines[bond,1] = coordVec[point,1]
        lines[bond,2] = coordVec[j_point_id,0]
        lines[bond,3] = coordVec[j_point_id,1]

# %%
import matplotlib.pyplot as plt
import matplotlib

# Create a new figure
fig, ax = plt.subplots(figsize=(15, 8))
# Loop through each line and plot it
for line in range(lines.shape[0]):
    if line%500 == 0:
        if fatigueModelData.bondMaterialIDarray[line] == 0:
            color = "g"
            linewidth = 0.1
        elif fatigueModelData.bondMaterialIDarray[line] == 1:
            color = "r"
            linewidth = 0.1
        elif fatigueModelData.bondMaterialIDarray[line] == 2:
            color = "k"
            linewidth = 0.1
        else:
            color = "b"
            linewidth = 0.5
    # Extract x and y coordinates for the line
        x_values = [lines[line,0],lines[line,2]]
        y_values = [lines[line,1],lines[line,3]]

    # Plot the line
        ax.plot(x_values, y_values,linewidth = linewidth, c=color)

ax.set_aspect(1)
# Set plot title and labels
plt.title('Lines Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.gca().set_aspect(1)
# Display the plot
plt.grid(True)

# %%
solver = PDFatigueSolver(numModel=model0)
solver.FID.num_max_it = 30
solver.solve_for_static_eq() # change the BCvec!!! Roght now its only a temporary fix!!! The last input in the BC vec was wrong somehow!
#forceDensVec = solver.solve_lin_sys(disps = disps.flatten())
# Out:
# Iteration 0
# Residual force norm =  0.0010836870488648565
# Change of residual from previous step: 0.9989163129511351
# Iteration 1
# Residual force norm =  0.0005022235553562293
# Change of residual from previous step: 0.5365603419526884
# Iteration 2
# Residual force norm =  0.00026765994637001356
# Change of residual from previous step: 0.4670501940512105
# Iteration 3
# Residual force norm =  0.00019271011372468116
# Change of residual from previous step: 0.28001885848740926
# Iteration 4
# Residual force norm =  0.0001287693157152603
# Change of residual from previous step: 0.33179783236893867
# Iteration 5
# Residual force norm =  8.944558293966232e-05
# Change of residual from previous step: 0.30538123587262156
# Iteration 6
# Residual force norm =  6.555491740822816e-05
# Change of residual from previous step: 0.26709720867435316
# Iteration 7
# Residual force norm =  5.142450387896069e-05
# Change of residual from previous step: 0.2155507792233735
# Iteration 8
# Residual force norm =  3.8327917509128895e-05
# Change of residual from previous step: 0.25467598872042796
# Iteration 9
# Residual force norm =  3.1639501883784504e-05
# Change of residual from previous step: 0.17450506210652728
# Iteration 10
# Residual force norm =  2.619857163432826e-05
# Change of residual from previous step: 0.17196636879560878
# Iteration 11
# Residual force norm =  2.3008730703599767e-05
# Change of residual from previous step: 0.12175629172656166
# Iteration 12
# Residual force norm =  1.942986332537089e-05
# Change of residual from previous step: 0.15554388568114086
# Iteration 13
# Residual force norm =  1.6778199137812422e-05
# Change of residual from previous step: 0.13647364076390645
# Iteration 14
# Residual force norm =  1.4020973635009426e-05
# Change of residual from previous step: 0.16433381676756575
# Iteration 15
# Residual force norm =  1.210917949290291e-05
# Change of residual from previous step: 0.13635245253816708
# Iteration 16
# Residual force norm =  1.0484502669161344e-05
# Change of residual from previous step: 0.13416902645582018
# Iteration 17
# Residual force norm =  9.149887501447296e-06
# Change of residual from previous step: 0.12729408440513124
# Iteration 18
# Residual force norm =  8.04893319439337e-06
# Change of residual from previous step: 0.12032435446662926
# Iteration 19
# Residual force norm =  7.072908374761155e-06
# Change of residual from previous step: 0.12126138906359452
# Iteration 20
# Residual force norm =  6.164140755826608e-06
# Change of residual from previous step: 0.1284857050004179
# Iteration 21
# Residual force norm =  5.553309276651319e-06
# Change of residual from previous step: 0.09909434313256149
# Damage has converged in 21 steps!
# Residual forces/Externalforces = 5.553309276651319e-06
# Change of residual from previous step: 0.09909434313256149

# %%
end_of_static_state = solver.HistoryOutput.history[0]
disp = end_of_static_state.state_data["displacements"]
coordVecNew4 = coordVec + disp

# %%
point_damage = np.zeros_like(solver.FID.n_neighbors,dtype=float)
bond_life = solver.FID.curLiveBonds
strt = solver.FID.start_idx
end = solver.FID.end_idx
for point in range(solver.FID.coordVec.shape[0]): 
    point_damage[point] = 1.0 - (np.sum(bond_life[strt[point]:end[point]]))/np.float64(solver.FID.n_neighbors[point])
    
# bond_stifnesses = solver.gen_bond_stiffness_matrices()
# bond_displacement_diff = solver.gen_bond_displacement_vecs(disps)
# force_dens_vecs = pddo.generate_force_dens_vecs(bond_stifnesses,bond_displacement_diff)
# bond_lens = pddo.calc_bondLenghts(solver.FID.coordVec,solver.FID.neighbors,solver.FID.start_idx,solver.FID.end_idx)
# bond_len_change = solver.calc_bond_stretches(coordVecNew4) * bond_lens
# bond_micro_potentials = np.linalg.norm(force_dens_vecs,axis=1) * bond_len_change /2
# point_SED = pddo.family_integration(solver.FID.neighbors,solver.FID.start_idx,solver.FID.end_idx,bond_micro_potentials,solver.FID.ptVolumes)/2

# %%
s = 2
#mycmap = matplotlib.colors.LinearSegmentedColormap.from_list("custom",["blue","royalblue","cyan","mediumspringgreen","springgreen","lime","lawngreen","yellow","orange","tomato","red"],N=11)
mycmap = matplotlib.colors.LinearSegmentedColormap.from_list("custom",["blue","royalblue","cyan","mediumspringgreen","springgreen","lime","lawngreen","yellow","orange","tomato","red"])
#mycmap = matplotlib.colors.LinearSegmentedColormap.from_list("custom",["blue","cyan","green","yellow","orange","red"])
fig1 = plt.figure(figsize=(22,12))

## Nedeformirana oblika
ax0 = fig1.add_subplot(2,3,1)
# ax0.plot(coordVec[:,0],coordVec[:totint,1],'co',markersize=1)
# ax0.plot(coordVec[totint:totbottom,0],coordVec[totint:totbottom,1],"ro",markersize=1)
ax0.plot(coordVec[:,0],coordVec[:,1],"bo",markersize=1)
ax0.set_aspect("1")
plt.xlabel("x [m]")
plt.ylabel("y [m]")

##Deformirana oblika
ax1 = fig1.add_subplot(2,3,2)
ax1.plot(coordVecNew4[:,0],coordVecNew4[:,1],'co',markersize=s)
# ax1.plot(coordVecNew4[:,0],coordVecNew4[:,1],"ro",markersize=s)
# ax1.plot(coordVecNew4[:,0],coordVecNew4[:,1],"bo",markersize=s)
ax1.set_aspect("1")
plt.xlabel("x [m]")
plt.ylabel("y [m]")

##Strain energy density
ax5 = fig1.add_subplot(2,3,3)
# sc5 = ax5.tricontourf(coordVec[:,0],coordVec[:,1],point_damage,cmap=mycmap,vmin = 0, vmax =0.5)#,c=point_SED)
sc5 = ax5.scatter(coordVecNew4[:,0],coordVecNew4[:,1],c=point_damage*1000,s=0.1,cmap = mycmap)
# # ax5.set_ylim(0.015,0.025)
ax5.set_aspect("1")
# plt.title("SED [N/mm**2]")
plt.colorbar(sc5)
# plt.xlabel("x [m]")
# plt.ylabel("y [m]")

## Absolutni pomiki
ax2 = fig1.add_subplot(2,3,4)
ax2.set_aspect("1")
#h = np.sqrt(disp[:,0]*disp[:totint,0]+disp[:totint,1]*disp[:totint,1])*1000
h = np.sqrt(disp[:,0]*disp[:,0]+disp[:,1]*disp[:,1])*1000
cm = plt.cm.get_cmap('RdYlBu')
#sc = ax.scatter(coordVecNew4[:totint,0],coordVecNew4[:totint,1],s=s,c=h,cmap=mycmap)
#p1=coordVec[:totint,0].reshape(100,100)
#p2=coordVec[:totint,1].reshape(100,100)
#sc = ax.contourf(p1,p2,h.reshape(100,100),cmap=mycmap)
sc = ax2.scatter(coordVecNew4[:,0],coordVecNew4[:,1],s=s,c=h[:],cmap=mycmap)
#sc3 = ax.scatter(coordVecNew4[totbottom:tottop,0],coordVecNew4[totbottom:tottop,1],s=s,c=h[totbottom:tottop],cmap=mycmap)

plt.title("Pomik [mm]")
plt.xlabel("x [m]")
plt.ylabel("y [m]")
v= np.linspace(np.min(h),np.max(h),12,endpoint=True)
plt.colorbar(sc,ticks=v)

##Pomiki X
ax3 = fig1.add_subplot(2,3,5)
ax3.set_aspect("1")
# h1 = disp[:totint,0]*1000
h1 = disp[:tottop,0]*1000
vm=h1#np.max(disp[:tottop,0])
cm1 = plt.cm.get_cmap('RdYlBu')
sc1 = ax3.scatter(coordVecNew4[:,0],coordVecNew4[:,1],s=s,c=h1[:],cmap=mycmap)
plt.title("Pomik v x [mm]")
plt.xlabel("x [m]")
plt.ylabel("y [m]")
v1= np.linspace(np.min(h1),np.max(h1),12,endpoint=True)
# plt.colorbar(sc1,ticks=v1)

##Pomiki Y
ax4 = fig1.add_subplot(2,3,6)
ax4.set_aspect("1")
h2 = disp[:,1]*1000
cm2 = plt.cm.get_cmap('RdYlBu')
#sc2 = plt.scatter(coordVecNew4[:,0],coordVecNew4[:,1],s=s,c=h2[:],cmap=mycmap)
sc2 = plt.scatter(coordVecNew4[:,0],coordVecNew4[:,1],s=s,c=h2[:],cmap=mycmap)
plt.title("Pomik v y [mm]")
plt.xlabel("x [m]")
plt.ylabel("y [m]")
v2= np.linspace(np.min(h2),np.max(h2),12,endpoint=True)
# plt.colorbar(sc2,ticks=v2)

# %%
solver.solve_for_fatigue_eq(inputState = end_of_static_state,cycle_increment=1000000)
# Out:
# WARNING: s_max not specified. Setting s_max array = bondStretches array (bondStretches from inputState)
# c:\Users\Filip Jerenec\Python\GitHub repos\Verse2\src\modules\PDFatigueModel.py:590: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "_calculate_fatigue_damage_increment" failed type inference due to: Untyped global name 'lambertw': Cannot determine Numba type of <class 'function'>
#
# File "..\src\modules\PDFatigueModel.py", line 632:
# def _calculate_fatigue_damage_increment(
#     <source elided>
#             f = np.exp(d * e)
#             fatigue_damage_increments[bond] = a * np.real(lambertw(b * c * f))
#             ^
#
#   @jit
# c:\Users\Filip Jerenec\Python\GitHub repos\Verse2\src\modules\PDFatigueModel.py:590: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "_calculate_fatigue_damage_increment" failed type inference due to: Cannot determine Numba type of <class 'numba.core.dispatcher.LiftedLoop'>
#
# File "..\src\modules\PDFatigueModel.py", line 623:
# def _calculate_fatigue_damage_increment(
#     <source elided>
#     fatigue_damage_increments = np.zeros_like(current_bond_stretches)
#     for bond in prange(current_bond_stretches.shape[0]):
#     ^
#
#   @jit
# c:\Users\Filip Jerenec\envs\PDenv\lib\site-packages\numba\core\object_mode_passes.py:151: NumbaWarning: Function "_calculate_fatigue_damage_increment" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "..\src\modules\PDFatigueModel.py", line 622:
# def _calculate_fatigue_damage_increment(
#     <source elided>
#     """
#     fatigue_damage_increments = np.zeros_like(current_bond_stretches)
#     ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# c:\Users\Filip Jerenec\envs\PDenv\lib\site-packages\numba\core\object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\src\modules\PDFatigueModel.py", line 622:
# def _calculate_fatigue_damage_increment(
#     <source elided>
#     """
#     fatigue_damage_increments = np.zeros_like(current_bond_stretches)
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# c:\Users\Filip Jerenec\Python\GitHub repos\Verse2\src\modules\PDFatigueModel.py:590: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "_calculate_fatigue_damage_increment" failed type inference due to: Untyped global name 'lambertw': Cannot determine Numba type of <class 'function'>
#
# File "..\src\modules\PDFatigueModel.py", line 632:
# def _calculate_fatigue_damage_increment(
#     <source elided>
#             f = np.exp(d * e)
#             fatigue_damage_increments[bond] = a * np.real(lambertw(b * c * f))
#             ^
#
#   @jit
# c:\Users\Filip Jerenec\envs\PDenv\lib\site-packages\numba\core\object_mode_passes.py:151: NumbaWarning: Function "_calculate_fatigue_damage_increment" was compiled in object mode without forceobj=True.
#
# File "..\src\modules\PDFatigueModel.py", line 623:
# def _calculate_fatigue_damage_increment(
#     <source elided>
#     fatigue_damage_increments = np.zeros_like(current_bond_stretches)
#     for bond in prange(current_bond_stretches.shape[0]):
#     ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# c:\Users\Filip Jerenec\envs\PDenv\lib\site-packages\numba\core\object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\src\modules\PDFatigueModel.py", line 623:
# def _calculate_fatigue_damage_increment(
#     <source elided>
#     fatigue_damage_increments = np.zeros_like(current_bond_stretches)
#     for bond in prange(current_bond_stretches.shape[0]):
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# Max fatigue damage increment =  0.8384848706877298
# iter 0
# Normalized residual force =  1.9779905524597297e-06
# Fraction of residual from previous iter: 0.9999980220094475
# Fractional change of residual from previous iter: 1.9779905524597297e-06
# --------------------------------------------------------
# Damage has converged in 0 FATIGUE CRACK GROWTH iter/s!. Tolerance = 0.1
# Residual forces/Externalforces = 1.9779905524597297e-06
# Fraction of residual from previous iter: 0.9999980220094475
# Fractional change of residual from previous iter: 1.9779905524597297e-06 -> Fraction + Fractional change = 1
# Nubmer of bonds broken during fatigue step = 218.0.

# %%
test_history = solver.local_history_output.history
disp = test_history[1].state_data["displacements"]
coordVecNew4 = coordVec + disp

# %%
step_history = []
prev_step_history_state = end_of_static_state
for step in range (20):
    solver.solve_for_fatigue_eq(inputState = prev_step_history_state,cycle_increment=1000000)
    prev_step_history_state = solver.local_history_output.history[1]
    step_history.append(prev_step_history_state)
# Out:
# Max fatigue damage increment =  0.8384848706877298
# iter 0
# Normalized residual force =  1.9779905524597297e-06
# Fraction of residual from previous iter: 0.9999980220094475
# Fractional change of residual from previous iter: 1.9779905524597297e-06
# --------------------------------------------------------
# Damage has converged in 0 FATIGUE CRACK GROWTH iter/s!. Tolerance = 0.1
# Residual forces/Externalforces = 1.9779905524597297e-06
# Fraction of residual from previous iter: 0.9999980220094475
# Fractional change of residual from previous iter: 1.9779905524597297e-06 -> Fraction + Fractional change = 1
# Nubmer of bonds broken during fatigue step = 218.0.
# Max fatigue damage increment =  0.016378623976399956
# iter 0
# Normalized residual force =  2.0838644012588503e-06
# Fraction of residual from previous iter: 0.9999979161355987
# Fractional change of residual from previous iter: 2.0838644012588503e-06
# --------------------------------------------------------
# Damage has converged in 0 FATIGUE CRACK GROWTH iter/s!. Tolerance = 0.1
# Residual forces/Externalforces = 2.0838644012588503e-06
# Fraction of residual from previous iter: 0.9999979161355987
# Fractional change of residual from previous iter: 2.0838644012588503e-06 -> Fraction + Fractional change = 1
# Nubmer of bonds broken during fatigue step = 14.0.
# Max fatigue damage increment =  0.010336378076739556
# iter 0
# Normalized residual force =  2.1823010540877874e-06
# Fraction of residual from previous iter: 0.9999978176989459
# Fractional change of residual from previous iter: 2.1823010540877874e-06
# --------------------------------------------------------
# Damage has converged in 0 FATIGUE CRACK GROWTH iter/s!. Tolerance = 0.1
# Residual forces/Externalforces = 2.1823010540877874e-06
# Fraction of residual from previous iter: 0.9999978176989459
# Fractional change of residual from previous iter: 2.1823010540877874e-06 -> Fraction + Fractional change = 1
# Nubmer of bonds broken during fatigue step = 8.0.
# Max fatigue damage increment =  0.007592475878041152
# iter 0
# Normalized residual force =  2.2660082741321474e-06
# Fraction of residual from previous iter: 0.9999977339917259
# Fractional change of residual from previous iter: 2.2660082741321474e-06
# --------------------------------------------------------
# Damage has converged in 0 FATIGUE CRACK GROWTH iter/s!. Tolerance = 0.1
# Residual forces/Externalforces = 2.2660082741321474e-06
# Fraction of residual from previous iter: 0.9999977339917259
# Fractional change of residual from previous iter: 2.2660082741321474e-06 -> Fraction + Fractional change = 1
# Nubmer of bonds broken during fatigue step = 8.0.
# Max fatigue damage increment =  0.005685987860729445
# iter 0
# Normalized residual force =  2.3476351156404007e-06
# Fraction of residual from previous iter: 0.9999976523648844
# Fractional change of residual from previous iter: 2.3476351156404007e-06
# --------------------------------------------------------
# Damage has converged in 0 FATIGUE CRACK GROWTH iter/s!. Tolerance = 0.1
# Residual forces/Externalforces = 2.3476351156404007e-06
# Fraction of residual from previous iter: 0.9999976523648844
# Fractional change of residual from previous iter: 2.3476351156404007e-06 -> Fraction + Fractional change = 1
# Nubmer of bonds broken during fatigue step = 4.0.
# Max fatigue damage increment =  0.005224029289522454
# iter 0
# Normalized residual force =  2.4250579657714155e-06
# Fraction of residual from previous iter: 0.9999975749420342
# Fractional change of residual from previous iter: 2.4250579657714155e-06
# --------------------------------------------------------
# Damage has converged in 0 FATIGUE CRACK GROWTH iter/s!. Tolerance = 0.1
# Residual forces/Externalforces = 2.4250579657714155e-06
# Fraction of residual from previous iter: 0.9999975749420342
# Fractional change of residual from previous iter: 2.4250579657714155e-06 -> Fraction + Fractional change = 1
# Nubmer of bonds broken during fatigue step = 2.0.
# Max fatigue damage increment =  0.004630701100698456
# iter 0
# Normalized residual force =  2.501592790915552e-06
# Fraction of residual from previous iter: 0.9999974984072091
# Fractional change of residual from previous iter: 2.501592790915552e-06
# --------------------------------------------------------
# Damage has converged in 0 FATIGUE CRACK GROWTH iter/s!. Tolerance = 0.1
# Residual forces/Externalforces = 2.501592790915552e-06
# Fraction of residual from previous iter: 0.9999974984072091
# Fractional change of residual from previous iter: 2.501592790915552e-06 -> Fraction + Fractional change = 1
# Nubmer of bonds broken during fatigue step = 8.0.
# Max fatigue damage increment =  0.00431426224907977
# iter 0
# Normalized residual force =  2.561189891503446e-06
# Fraction of residual from previous iter: 0.9999974388101085
# Fractional change of residual from previous iter: 2.561189891503446e-06
# --------------------------------------------------------
# Damage has converged in 0 FATIGUE CRACK GROWTH iter/s!. Tolerance = 0.1
# Residual forces/Externalforces = 2.561189891503446e-06
# Fraction of residual from previous iter: 0.9999974388101085
# Fractional change of residual from previous iter: 2.561189891503446e-06 -> Fraction + Fractional change = 1
# Nubmer of bonds broken during fatigue step = 6.0.
# Max fatigue damage increment =  0.0038343718280604883
# iter 0
# Normalized residual force =  2.615101781122675e-06
# Fraction of residual from previous iter: 0.9999973848982189
# Fractional change of residual from previous iter: 2.615101781122675e-06
# --------------------------------------------------------
# Damage has converged in 0 FATIGUE CRACK GROWTH iter/s!. Tolerance = 0.1
# Residual forces/Externalforces = 2.615101781122675e-06
# Fraction of residual from previous iter: 0.9999973848982189
# Fractional change of residual from previous iter: 2.615101781122675e-06 -> Fraction + Fractional change = 1
# Nubmer of bonds broken during fatigue step = 4.0.
# Max fatigue damage increment =  0.0027175748952327286
# iter 0
# Normalized residual force =  2.6672223552015595e-06
# Fraction of residual from previous iter: 0.9999973327776448
# Fractional change of residual from previous iter: 2.6672223552015595e-06
# --------------------------------------------------------
# Damage has converged in 0 FATIGUE CRACK GROWTH iter/s!. Tolerance = 0.1
# Residual forces/Externalforces = 2.6672223552015595e-06
# Fraction of residual from previous iter: 0.9999973327776448
# Fractional change of residual from previous iter: 2.6672223552015595e-06 -> Fraction + Fractional change = 1
# Nubmer of bonds broken during fatigue step = 0.0.
# Max fatigue damage increment =  0.0027175748952327286
# iter 0
# Normalized residual force =  2.7197986123272955e-06
# Fraction of residual from previous iter: 0.9999972802013877
# Fractional change of residual from previous iter: 2.7197986123272955e-06
# --------------------------------------------------------
# Damage has converged in 0 FATIGUE CRACK GROWTH iter/s!. Tolerance = 0.1
# Residual forces/Externalforces = 2.7197986123272955e-06
# Fraction of residual from previous iter: 0.9999972802013877
# Fractional change of residual from previous iter: 2.7197986123272955e-06 -> Fraction + Fractional change = 1
# Nubmer of bonds broken during fatigue step = 0.0.
# Max fatigue damage increment =  0.0027175748952327286
# iter 0
# Normalized residual force =  2.772830595798581e-06
# Fraction of residual from previous iter: 0.9999972271694042
# Fractional change of residual from previous iter: 2.772830595798581e-06
# --------------------------------------------------------
# Damage has converged in 0 FATIGUE CRACK GROWTH iter/s!. Tolerance = 0.1
# Residual forces/Externalforces = 2.772830595798581e-06
# Fraction of residual from previous iter: 0.9999972271694042
# Fractional change of residual from previous iter: 2.772830595798581e-06 -> Fraction + Fractional change = 1
# Nubmer of bonds broken during fatigue step = 0.0.
# Max fatigue damage increment =  0.0027175748952327286
# iter 0
# Normalized residual force =  2.8263183482479803e-06
# Fraction of residual from previous iter: 0.9999971736816518
# Fractional change of residual from previous iter: 2.8263183482479803e-06
# --------------------------------------------------------
# Damage has converged in 0 FATIGUE CRACK GROWTH iter/s!. Tolerance = 0.1
# Residual forces/Externalforces = 2.8263183482479803e-06
# Fraction of residual from previous iter: 0.9999971736816518
# Fractional change of residual from previous iter: 2.8263183482479803e-06 -> Fraction + Fractional change = 1
# Nubmer of bonds broken during fatigue step = 0.0.
# Max fatigue damage increment =  0.0027175748952327286
# iter 0
# Normalized residual force =  2.878732688227359e-06
# Fraction of residual from previous iter: 0.9999971212673118
# Fractional change of residual from previous iter: 2.878732688227359e-06
# --------------------------------------------------------
# Damage has converged in 0 FATIGUE CRACK GROWTH iter/s!. Tolerance = 0.1
# Residual forces/Externalforces = 2.878732688227359e-06
# Fraction of residual from previous iter: 0.9999971212673118
# Fractional change of residual from previous iter: 2.878732688227359e-06 -> Fraction + Fractional change = 1
# Nubmer of bonds broken during fatigue step = 4.0.
# Max fatigue damage increment =  0.0026363959032982974
# iter 0
# Normalized residual force =  2.9268303587404176e-06
# Fraction of residual from previous iter: 0.9999970731696413
# Fractional change of residual from previous iter: 2.9268303587404176e-06
# --------------------------------------------------------
# Damage has converged in 0 FATIGUE CRACK GROWTH iter/s!. Tolerance = 0.1
# Residual forces/Externalforces = 2.9268303587404176e-06
# Fraction of residual from previous iter: 0.9999970731696413
# Fractional change of residual from previous iter: 2.9268303587404176e-06 -> Fraction + Fractional change = 1
# Nubmer of bonds broken during fatigue step = 4.0.
# Max fatigue damage increment =  0.0019109047424215482
# iter 0
# Normalized residual force =  2.9745965208771707e-06
# Fraction of residual from previous iter: 0.9999970254034791
# Fractional change of residual from previous iter: 2.9745965208771707e-06
# --------------------------------------------------------
# Damage has converged in 0 FATIGUE CRACK GROWTH iter/s!. Tolerance = 0.1
# Residual forces/Externalforces = 2.9745965208771707e-06
# Fraction of residual from previous iter: 0.9999970254034791
# Fractional change of residual from previous iter: 2.9745965208771707e-06 -> Fraction + Fractional change = 1
# Nubmer of bonds broken during fatigue step = 0.0.
# Max fatigue damage increment =  0.0019109047424215482
# iter 0
# Normalized residual force =  3.0225684894968907e-06
# Fraction of residual from previous iter: 0.9999969774315105
# Fractional change of residual from previous iter: 3.0225684894968907e-06
# --------------------------------------------------------
# Damage has converged in 0 FATIGUE CRACK GROWTH iter/s!. Tolerance = 0.1
# Residual forces/Externalforces = 3.0225684894968907e-06
# Fraction of residual from previous iter: 0.9999969774315105
# Fractional change of residual from previous iter: 3.0225684894968907e-06 -> Fraction + Fractional change = 1
# Nubmer of bonds broken during fatigue step = 0.0.
# Max fatigue damage increment =  0.0019109047424215482
# iter 0
# Normalized residual force =  3.070746283473369e-06
# Fraction of residual from previous iter: 0.9999969292537165
# Fractional change of residual from previous iter: 3.070746283473369e-06
# --------------------------------------------------------
# Damage has converged in 0 FATIGUE CRACK GROWTH iter/s!. Tolerance = 0.1
# Residual forces/Externalforces = 3.070746283473369e-06
# Fraction of residual from previous iter: 0.9999969292537165
# Fractional change of residual from previous iter: 3.070746283473369e-06 -> Fraction + Fractional change = 1
# Nubmer of bonds broken during fatigue step = 0.0.
# Max fatigue damage increment =  0.0019109047424215482
# iter 0
# Normalized residual force =  3.1191299230126646e-06
# Fraction of residual from previous iter: 0.999996880870077
# Fractional change of residual from previous iter: 3.1191299230126646e-06
# --------------------------------------------------------
# Damage has converged in 0 FATIGUE CRACK GROWTH iter/s!. Tolerance = 0.1
# Residual forces/Externalforces = 3.1191299230126646e-06
# Fraction of residual from previous iter: 0.999996880870077
# Fractional change of residual from previous iter: 3.1191299230126646e-06 -> Fraction + Fractional change = 1
# Nubmer of bonds broken during fatigue step = 0.0.
# Max fatigue damage increment =  0.0019109047424215482
# iter 0
# Normalized residual force =  3.1677194272106135e-06
# Fraction of residual from previous iter: 0.9999968322805728
# Fractional change of residual from previous iter: 3.1677194272106135e-06
# --------------------------------------------------------
# Damage has converged in 0 FATIGUE CRACK GROWTH iter/s!. Tolerance = 0.1
# Residual forces/Externalforces = 3.1677194272106135e-06
# Fraction of residual from previous iter: 0.9999968322805728
# Fractional change of residual from previous iter: 3.1677194272106135e-06 -> Fraction + Fractional change = 1
# Nubmer of bonds broken during fatigue step = 0.0.

# %%
point_damage = solver.calc_point_damage(step_history[-1])
point_damage_end_static = solver.calc_point_damage(end_of_static_state)

# %%
s = 1
#mycmap = matplotlib.colors.LinearSegmentedColormap.from_list("custom",["blue","royalblue","cyan","mediumspringgreen","springgreen","lime","lawngreen","yellow","orange","tomato","red"],N=11)
mycmap = matplotlib.colors.LinearSegmentedColormap.from_list("custom",["blue","royalblue","cyan","mediumspringgreen","springgreen","lime","lawngreen","yellow","orange","tomato","red"])
#mycmap = matplotlib.colors.LinearSegmentedColormap.from_list("custom",["blue","cyan","green","yellow","orange","red"])
fig1 = plt.figure(figsize=(52,12))

# ## Nedeformirana oblika
ax0 = fig1.add_subplot(2,3,6)
# ax0.plot(coordVec[:,0],coordVec[:totint,1],'co',markersize=1)
# ax0.plot(coordVec[totint:totbottom,0],coordVec[totint:totbottom,1],"ro",markersize=1)
ax0.scatter(coordVecNew4[:,0],coordVecNew4[:,1],c=point_damage*1000,s=s,cmap = mycmap)
ax0.set_aspect("1")
plt.xlabel("x [m]")
plt.ylabel("y [m]")

# #Deformirana oblika
# ax1 = fig1.add_subplot(2,3,2)
# ax1.plot(coordVecNew4[:,0],coordVecNew4[:,1],'co',markersize=s)
# ax1.plot(coordVecNew4[:,0],coordVecNew4[:,1],"ro",markersize=s)
# ax1.plot(coordVecNew4[:,0],coordVecNew4[:,1],"bo",markersize=s)
# ax1.set_aspect("1")
# plt.xlabel("x [m]")
# plt.ylabel("y [m]")

##Strain energy density
ax5 = fig1.add_subplot(2,3,3)
# sc5 = ax5.tricontourf(coordVec[:,0],coordVec[:,1],point_damage,cmap=mycmap,vmin = 0, vmax =0.5)#,c=point_SED)
sc5 = ax5.scatter(coordVecNew4[:,0],coordVecNew4[:,1],c=point_damage*1000,s=s,cmap = mycmap)
# # ax5.set_ylim(0.015,0.025)
ax5.set_aspect("1")
# plt.title("SED [N/mm**2]")
plt.colorbar(sc5)
# plt.xlabel("x [m]")
# plt.ylabel("y [m]")

# ## Absolutni pomiki
# ax2 = fig1.add_subplot(2,3,4)
# ax2.set_aspect("1")
# #h = np.sqrt(disp[:,0]*disp[:totint,0]+disp[:totint,1]*disp[:totint,1])*1000
# h = np.sqrt(disp[:,0]*disp[:,0]+disp[:,1]*disp[:,1])*1000
# cm = plt.cm.get_cmap('RdYlBu')
# #sc = ax.scatter(coordVecNew4[:totint,0],coordVecNew4[:totint,1],s=s,c=h,cmap=mycmap)
# #p1=coordVec[:totint,0].reshape(100,100)
# #p2=coordVec[:totint,1].reshape(100,100)
# #sc = ax.contourf(p1,p2,h.reshape(100,100),cmap=mycmap)
# sc = ax2.scatter(coordVecNew4[:,0],coordVecNew4[:,1],s=s,c=h[:],cmap=mycmap)
# #sc3 = ax.scatter(coordVecNew4[totbottom:tottop,0],coordVecNew4[totbottom:tottop,1],s=s,c=h[totbottom:tottop],cmap=mycmap)

# plt.title("Pomik [mm]")
# plt.xlabel("x [m]")
# plt.ylabel("y [m]")
# v= np.linspace(np.min(h),np.max(h),12,endpoint=True)
# plt.colorbar(sc,ticks=v)

# ##Pomiki X
# ax3 = fig1.add_subplot(2,3,5)
# ax3.set_aspect("1")
# # h1 = disp[:totint,0]*1000
# h1 = disp[:tottop,0]*1000
# vm=h1#np.max(disp[:tottop,0])
# cm1 = plt.cm.get_cmap('RdYlBu')
# sc1 = ax3.scatter(coordVecNew4[:,0],coordVecNew4[:,1],s=s,c=h1[:],cmap=mycmap)
# plt.title("Pomik v x [mm]")
# plt.xlabel("x [m]")
# plt.ylabel("y [m]")
# v1= np.linspace(np.min(h1),np.max(h1),12,endpoint=True)
# # plt.colorbar(sc1,ticks=v1)

# ##Pomiki Y
# ax4 = fig1.add_subplot(2,3,6)
# ax4.set_aspect("1")
# h2 = disp[:,1]*1000
# cm2 = plt.cm.get_cmap('RdYlBu')
# #sc2 = plt.scatter(coordVecNew4[:,0],coordVecNew4[:,1],s=s,c=h2[:],cmap=mycmap)
# sc2 = plt.scatter(coordVecNew4[:,0],coordVecNew4[:,1],s=s,c=h2[:],cmap=mycmap)
# plt.title("Pomik v y [mm]")
# plt.xlabel("x [m]")
# plt.ylabel("y [m]")
# v2= np.linspace(np.min(h2),np.max(h2),12,endpoint=True)
# # plt.colorbar(sc2,ticks=v2)

# %%
end_of_fat_state_live_bonds = test_history[1].state_data["LiveBonds"] 
livebonds = np.ones_like(end_of_fat_state_live_bonds)
alive = True
for bond in range(livebonds.shape[0]):
    if end_of_static_state.state_data["LiveBonds"][bond] == alive and end_of_fat_state_live_bonds[bond] != alive:
        livebonds[bond] = not alive

# Create a new figure
fig, ax = plt.subplots(figsize=(15, 8))
# Loop through each line and plot it
broken_plots = 0
for line in range(lines.shape[0]):
    if livebonds[line] == alive and end_of_static_state.state_data["LiveBonds"][line] == alive:
        if line%5 == 0:
            if fatigueModelData.bondMaterialIDarray[line] == 0:
                color = "g"
                linewidth = 0.1
            elif fatigueModelData.bondMaterialIDarray[line] == 1:
                color = "r"
                linewidth = 0.1
            elif fatigueModelData.bondMaterialIDarray[line] == 2:
                color = "k"
                linewidth = 0.1
            else:
                color = "b"
                linewidth = 0.5

            # Extract x and y coordinates for the line
            x_values = [lines[line,0],lines[line,2]]
            y_values = [lines[line,1],lines[line,3]]

            # Plot the line
            ax.plot(x_values, y_values,linewidth = linewidth, c=color)

    elif livebonds[line] != alive:
        broken_plots += 1
        color = "g"
        linewidth = 0.5
    
    # Extract x and y coordinates for the line
        x_values = [lines[line,0],lines[line,2]]
        y_values = [lines[line,1],lines[line,3]]

    # Plot the line
        ax.plot(x_values, y_values,linewidth = linewidth, c=color)
print(broken_plots)
ax.set_aspect(1)
# Set plot title and labels
plt.title('Lines Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.gca().set_aspect(1)
# Display the plot
plt.grid(True)
# Out:
# 218

# %%
plt.plot(solver.test1,label="test1")
# plt.plot(solver.test2)
plt.legend()
plt.show()
np.where(solver.test1 != 0)[0].shape,dx
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [35], line 1
# ----> 1 plt.plot(solver.test1,label="test1")
#       2 # plt.plot(solver.test2)
#       3 plt.legend()
#
# AttributeError: 'PDFatigueSolver' object has no attribute 'test1'
